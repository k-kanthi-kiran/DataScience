# %% [markdown]
# **Data Transformation**:
#
# Data Transformation techniques generally used for converting to normal distribution because all math analysis by assumption. Data follow normal distribution. It also avoids skewness. We have important transformation which are
# - Log Transformation
# - Exponential Transformation
# - Reciprocal Transformation
# - Square root Transformation
# - Power Transformation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filelocation="C:\\Users\\ADMIN\\Desktop\\Python\\Files\\Visadataset.csv"
visadf = pd.read_csv(filelocation)
visadf
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
exp_data=np.random.exponential(size=1000)
data
#We are considering exponential data set with random 1k observations from Numpy package
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 exp_data=np.random.exponential(size=1000)
# ----> 2 data
#
# NameError: name 'data' is not defined

# %%
norm_data=np.random.normal(size=1000)
norm_data
# Out:
# array([-2.15095994e+00,  1.33087738e-02,  2.20671934e+00, -1.80688605e+00,
#         1.34876734e+00,  6.55298496e-01, -9.87572057e-01,  1.66269290e+00,
#         2.62282513e-01, -1.43562155e+00, -1.02320243e+00, -2.14990157e+00,
#         1.36182403e-02,  9.73895760e-01,  4.50583496e-01, -1.10692313e+00,
#         5.27602566e-01,  9.01811117e-01, -2.12907894e-01, -6.63073114e-02,
#         1.39766767e+00,  1.05440061e+00,  2.93516114e-01,  1.94792776e-01,
#        -1.32992063e-01,  2.58825636e+00, -1.88428121e-01, -1.10510339e-01,
#         1.93140325e-01,  1.89082328e+00, -5.97026909e-01, -1.10680495e+00,
#        -2.14615161e-01, -5.51094209e-01,  1.08987340e+00, -1.62619907e+00,
#         1.59035673e+00,  6.97603020e-01, -2.01673324e-01,  1.69024234e+00,
#         3.17200623e+00, -5.70024699e-01,  4.81043677e-01, -8.42428466e-02,
#         1.46076940e+00,  1.34849409e+00, -1.20466363e+00,  1.73663154e+00,
# ...

# %%
plt.hist(exp_data,bins=30,label='Exponential')
plt.legend()
plt.show()

# %% [markdown]
# **Log transformation**
# np.log is used for log transformation generally log transformation will not convert data into normal. It avoids the skewness so np.log means natural logaritham base is e.Generally

# %%
log_data= np.log(exp_data)
log_data
# Out:
# array([-6.63780165e-01, -2.97566873e+00,  9.96376028e-01,  4.35512536e-01,
#        -1.54642862e+00,  7.65838630e-01, -9.46758238e-01,  7.61221053e-01,
#        -3.38020804e-01,  6.84800808e-01,  7.04588302e-01, -7.14643580e-01,
#        -8.75609794e-02,  5.84980202e-01,  1.35961677e-01,  1.05795968e+00,
#         8.40610343e-01, -3.46969228e+00, -3.89986049e-01, -1.07716420e+00,
#         8.71658372e-01, -1.56344456e+00, -1.34679233e-01, -1.19649798e+00,
#        -1.36345254e-01,  1.12777913e+00,  1.78737442e-01, -5.40090015e-01,
#        -4.69974565e-01, -1.02857134e+00,  9.66967831e-01, -1.30787128e+00,
#         7.78855601e-01, -3.65574560e-01, -2.82502069e-01, -9.87890504e-01,
#         4.89437354e-01, -1.84885985e+00, -3.12316261e+00, -1.58959137e+00,
#        -2.60902306e+00, -1.29698383e-01, -2.23527394e+00,  8.50631334e-01,
#        -6.40326088e-01, -1.94559630e-01, -5.88430930e-01, -2.60472685e-01,
# ...

# %%
plt.hist(log_data,bins=40,label='Log data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
 
plt.subplot(1,2,1).hist(exp_data,bins=40,label='Exponential')
plt.legend()
plt.subplot(1,2,2).hist(log_data,bins=40,label='Log Transformation')
plt.legend()
plt.show()

# %% [markdown]
# **Reciprocal Transformation**
#
# Receiprocal transformation fails when data has zero values.

# %%
recipro_data= np.reciprocal(exp_data)
plt.figure(figsize=(10,5))
plt.subplot(1,2,2).hist(recipro_data,bins=40,label='Reciprocal Transformation')
plt.legend()
plt.show()

# %% [markdown]
# **Square root Transformation**

# %%
#This is square
25**2 
#This is square root
25**1/2
print(np.sqrt(25))
sqrt_data = np.sqrt(exp_data)

# %%
plt.figure(figsize=(10,5))
 
plt.subplot(1,2,1).hist(exp_data,bins=40,label='Exponential')
plt.legend()
plt.subplot(1,2,2).hist(sqrt_data,bins=40,label='Sqrt Transformation')
plt.legend()
plt.show()

# %%
sns.histplot(sqrt_data)

# %% [markdown]
# **Power transformation**
# - It is related to sklearn package
# - Package name:sklearn.preprocessing
# - Method name: Power Transformer
# - Inside Box-Cox,yeo-jhonson

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
pt_data = pt.fit([[exp_data]]).transform([[exp_data]])
pt_data

# %%
plt.hist(pt_data[0])
