# %% [markdown]
# ############################# Exploratory  Data Analysis #############################
# 1. Pandas   (Data Frame analysis)
# 2. Numpy    (Number Python math Package)
# 3. Matplotlib ( plotting)
# 4. Seaborn    (Plotting)
# 5. Plotly     (Plotting)
# 6. Bokhe      (Plotting)
#
# ############################# Machine Learning ########################################
# 7.Scikit-Learn (ML models will be available)
# 8.Stats        (Statistical Models)
#
# ############################# Deep Learning ##########################################
# 9. Tensorflow            Developed by google
# 10. Keras
# 11. Torch
# 12. OpenCV              (Computer Vision) OpenCV:sentdex
# ############################# NLP ###################################################
# 13. NLTK                (Natural Language Tool Kit)
# 14. Scipy
# ############################# GenAI (LLM) ###################################################
# ###### Prompt Engineering
# 15. ChatGPT is developed by OpenAI+Azure
# 16. MakerSuite is developed by Google
# 17. Gemini  is developed by Google
# ########################### Company Based ####################################################
# 18. Hugging Face
#         Transformers       BERT models
#         DL ML NLP  all tasks it will do
#
# 19. AllenNLP
#
# ######### Special Packages ###########
# 20. Random
# 21. Time
# 22. Math
# 23. API Flask package
# 24. UI Apps Streamlit

# %%
Data Analysis
ML
DL
NLP
BERT: TRANSFORMERS
LLM : GenAI

# %%
CV means Computer Vision

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filelocation="C:\\Users\\ADMIN\\Desktop\\Python\\Files\\Visadataset.csv"
filecontent = pd.read_csv(filelocation)
filecontent
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
# ...

# %%
filelocation="C:\\Users\\ADMIN\\Desktop\\Python\\Files\\bank.csv"
pd.read_csv(filelocation)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# # How to create a data frame
# # How to add columns
# # How to add rows
# # How to drop columns
# # How to drop rows
# # How to save the data frame

# %%
# Method 1
# Creating a dataframe using list
Names=['Ramesh','Suresh','Sathish']
Age=[20,25,30]
pd.DataFrame(zip(Names,Age))
# Out:
#          0   1
# 0   Ramesh  20
# 1   Suresh  25
# 2  Sathish  30

# %%
#With Columns
Names=['Ramesh','Suresh','Sathish']
Age=[20,25,30]
pd.DataFrame(zip(Names,Age),columns=['Name','Age'])
# Out:
#       Name  Age
# 0   Ramesh   20
# 1   Suresh   25
# 2  Sathish   30

# %%
#With Index
Names=['Ramesh','Suresh','Sathish']
Age=[20,25,30]
pd.DataFrame(zip(Names,Age),columns=['Name','Age'],index=['A','B',100])
# Out:
#         Name  Age
# A     Ramesh   20
# B     Suresh   25
# 100  Sathish   30

# %%
#Create a new column and Adding to the frame
Names=['Ramesh','Suresh','Sathish']
Age=[20,25,30]
df1=pd.DataFrame(zip(Names,Age),columns=['Name','Age'],index=['A','B',100])
df1['City']=['Bangalore','Hyderabad','Chennai']
df1
# Out:
#         Name  Age       City
# A     Ramesh   20  Bangalore
# B     Suresh   25  Hyderabad
# 100  Sathish   30    Chennai

# %%
#Updating the data in the entire column 
df1['Name']=['Rambo','Arnold','Alex']
df1
# Out:
#        Name  Age       City
# A     Rambo   20  Bangalore
# B    Arnold   25  Hyderabad
# 100    Alex   30    Chennai

# %%
#Adding a row to dataframe using loc
Names=['Ramesh','Suresh','Sathish']
Age=[20,25,30]
df1=pd.DataFrame(zip(Names,Age),columns=['Name','Age'],index=['A','B',100])
df1.index
len(df1.index)
# Out:
# 3

# %%
#Changing the index from 'A','B',100 to 1,2,3 and Adding a row to dataframe
df1=pd.DataFrame(zip(Names,Age),columns=['Name','Age'],index=[0,1,2])
df1.loc[3]=['Bunny',40]
df1
df1.loc['A']=['Sunny',50]
df1
# Out:
#       Name  Age
# 0   Ramesh   20
# 1   Suresh   25
# 2  Sathish   30
# 3    Bunny   40
# A    Sunny   50

# %%
#Dropping the column using drop method which can be used for dropping column or row. 
# In this AXIS=1 references column and AXIS=0 references rows
Names=['Ramesh','Suresh','Sathish']
Age=[20,25,30]
df1=pd.DataFrame(zip(Names,Age),columns=['Name','Age'],index=[1,2,3])
df1['City']=['Bangalore','Hyderabad','Chennai']
df1.loc[3]=['Bunny',40,'Delhi']
df1.loc[4]=['Sunny',35,'Bihar']
df1.drop('City',axis=1) # Dropping city column , The data frame is not modified and on printing we get back the original
df1.drop('City',axis=1,inplace=True)
df1
# Out:
#      Name  Age
# 1  Ramesh   20
# 2  Suresh   25
# 3   Bunny   40
# 4   Sunny   35

# %%
df1.drop(1,inplace=True)
# Out:
#      Name  Age
# 2  Suresh   25
# 3   Bunny   40
# 4   Sunny   35

# %%
#Saving the data frame in local
df1.to_csv("C:\\Users\\ADMIN\\Desktop\\Python\\Files\\df1.csv",index=False)

# %%
#REading the file
pd.read_csv("C:\\Users\\ADMIN\\Desktop\\Python\\Files\\df1.csv")
# Out:
#      Name  Age
# 0  Ramesh   20
# 1  Suresh   25
# 2   Bunny   40
# 3   Sunny   35

# %%
#Method 2 :-
# Create a dataframe using dictionary
Names=['Ramesh','Suresh','Sathish']
Age=[20,25,30]
d1={'Names':['Ramesh','Suresh','Sathish'],
    'Age':[20,25,30]}
print("Dictionary:",d1)
pd.DataFrame(d1)
# Out:
# Dictionary: {'Names': ['Ramesh', 'Suresh', 'Sathish'], 'Age': [20, 25, 30]}
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   25
# 2  Sathish   30

# %%
# Method 3 
# Creating a empty data frame and adding the column and data at a later point. 
df1 = pd.DataFrame()
df1['Even']=[2,4,6,8]
df1['Odd']=[1,3,5,7]
df1
# Out:
#    Even  Odd
# 0     2    1
# 1     4    3
# 2     6    5
# 3     8    7
